# %%
# !pip install torch torchvision segmentation-models-pytorch opencv-python-headless
# Out:
# Requirement already satisfied: torch in /opt/conda/lib/python3.10/site-packages (2.4.0)
# Requirement already satisfied: torchvision in /opt/conda/lib/python3.10/site-packages (0.19.0)
# Collecting segmentation-models-pytorch
#   Downloading segmentation_models_pytorch-0.3.4-py3-none-any.whl.metadata (30 kB)
# Requirement already satisfied: opencv-python-headless in /opt/conda/lib/python3.10/site-packages (4.10.0.84)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch) (3.15.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /opt/conda/lib/python3.10/site-packages (from torch) (4.12.2)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch) (1.13.3)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch) (2024.6.1)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from torchvision) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /opt/conda/lib/python3.10/site-packages (from torchvision) (10.3.0)
# Collecting efficientnet-pytorch==0.7.1 (from segmentation-models-pytorch)
#   Downloading efficientnet_pytorch-0.7.1.tar.gz (21 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: huggingface-hub>=0.24.6 in /opt/conda/lib/python3.10/site-packages (from segmentation-models-pytorch) (0.25.1)
# Collecting pretrainedmodels==0.7.4 (from segmentation-models-pytorch)
#   Downloading pretrainedmodels-0.7.4.tar.gz (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 3.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: six in /opt/conda/lib/python3.10/site-packages (from segmentation-models-pytorch) (1.16.0)
# Collecting timm==0.9.7 (from segmentation-models-pytorch)
#   Downloading timm-0.9.7-py3-none-any.whl.metadata (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 3.4 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from segmentation-models-pytorch) (4.66.4)
# Collecting munch (from pretrainedmodels==0.7.4->segmentation-models-pytorch)
#   Downloading munch-4.0.0-py2.py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.10/site-packages (from timm==0.9.7->segmentation-models-pytorch) (6.0.2)
# Requirement already satisfied: safetensors in /opt/conda/lib/python3.10/site-packages (from timm==0.9.7->segmentation-models-pytorch) (0.4.5)
# Requirement already satisfied: packaging>=20.9 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.24.6->segmentation-models-pytorch) (21.3)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.24.6->segmentation-models-pytorch) (2.32.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->torch) (1.3.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=20.9->huggingface-hub>=0.24.6->segmentation-models-pytorch) (3.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub>=0.24.6->segmentation-models-pytorch) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub>=0.24.6->segmentation-models-pytorch) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub>=0.24.6->segmentation-models-pytorch) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub>=0.24.6->segmentation-models-pytorch) (2024.8.30)
# Downloading segmentation_models_pytorch-0.3.4-py3-none-any.whl (109 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 109.5/109.5 kB 5.9 MB/s eta 0:00:00
# Downloading timm-0.9.7-py3-none-any.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 39.2 MB/s eta 0:00:0000:01
# Downloading munch-4.0.0-py2.py3-none-any.whl (9.9 kB)
# Building wheels for collected packages: efficientnet-pytorch, pretrainedmodels
#   Building wheel for efficientnet-pytorch (setup.py) ... done
#   Created wheel for efficientnet-pytorch: filename=efficientnet_pytorch-0.7.1-py3-none-any.whl size=16427 sha256=656630429901d1d03ba726a81c3741956b6b752db361bd2638fa52b5cc0a1268
#   Stored in directory: /root/.cache/pip/wheels/03/3f/e9/911b1bc46869644912bda90a56bcf7b960f20b5187feea3baf
#   Building wheel for pretrainedmodels (setup.py) ... done
#   Created wheel for pretrainedmodels: filename=pretrainedmodels-0.7.4-py3-none-any.whl size=60945 sha256=164db82f5a71d4c9d038c35c3a334dc25c46e257831815cbf5a49780c82fd477
#   Stored in directory: /root/.cache/pip/wheels/35/cb/a5/8f534c60142835bfc889f9a482e4a67e0b817032d9c6883b64
# Successfully built efficientnet-pytorch pretrainedmodels
# Installing collected packages: munch, efficientnet-pytorch, timm, pretrainedmodels, segmentation-models-pytorch
#   Attempting uninstall: timm
#     Found existing installation: timm 1.0.9
#     Uninstalling timm-1.0.9:
#       Successfully uninstalled timm-1.0.9
# Successfully installed efficientnet-pytorch-0.7.1 munch-4.0.0 pretrainedmodels-0.7.4 segmentation-models-pytorch-0.3.4 timm-0.9.7

# %%
import os
import torch
from PIL import Image
import numpy as np
import torchvision.transforms as T
from tqdm import tqdm
from torchvision import models

class Label:
    def __init__(self, name, color):
        self.name = name
        self.color = color

# labels and colors
labels = [
    Label('road', (128, 64, 128)),
    Label('sidewalk', (244, 35, 232)),
    Label('building', (70, 70, 70)),
    Label('wall', (102, 102, 156)),
    Label('fence', (190, 153, 153)),
    Label('pole', (153, 153, 153)),
    Label('traffic light', (250, 170, 30)),
    Label('traffic sign', (220, 220, 0)),
    Label('vegetation', (107, 142, 35)),
    Label('terrain', (152, 251, 152)),
    Label('sky', (70, 130, 180)),
    Label('person', (220, 20, 60)),
    Label('rider', (255, 0, 0)),
    Label('car', (0, 0, 142)),
    Label('truck', (0, 0, 70)),
    Label('bus', (0, 60, 100)),
    Label('train', (0, 80, 100)),
    Label('motorcycle', (0, 0, 230)),
    Label('bicycle', (119, 11, 32))
]

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Loading HRnet
model = models.segmentation.deeplabv3_resnet101(pretrained=True).to(device)
model.eval()

# image transformation
transform = T.Compose([
    T.Resize((1024, 2048)), 
    T.ToTensor(),
    T.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

def decode_segmap(image, nc=21):
    label_colors = np.array([
        [0, 0, 0],       
        [128, 64, 128],  
        [244, 35, 232],  
        [70, 70, 70],    
        [102, 102, 156], 
        [190, 153, 153], 
        [153, 153, 153], 
        [250, 170, 30],  
        [220, 220, 0],   
        [107, 142, 35], 
        [152, 251, 152], 
        [70, 130, 180],  
        [220, 20, 60],   
        [255, 0, 0],     
        [0, 0, 142],     
        [0, 0, 70],      
        [0, 60, 100],    
        [0, 80, 100],    
        [0, 0, 230],     
        [119, 11, 32]   
    ])

    r = np.zeros_like(image).astype(np.uint8)
    g = np.zeros_like(image).astype(np.uint8)
    b = np.zeros_like(image).astype(np.uint8)

    for l in range(0, nc):
        idx = image == l
        r[idx] = label_colors[l, 0]
        g[idx] = label_colors[l, 1]
        b[idx] = label_colors[l, 2]

    rgb = np.stack([r, g, b], axis=2)
    return rgb

def segment_image(image_path):
    image = Image.open(image_path).convert('RGB')
    input_tensor = transform(image).unsqueeze(0).to(device)

    with torch.no_grad():
        output = model(input_tensor)['out']
    output_predictions = output.argmax(1).cpu().numpy()[0]

    decoded_image = decode_segmap(output_predictions, nc=len(labels))
    
    return decoded_image

def process_test_images(test_images, test_dir, output_dir):
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    for img_file in tqdm(test_images):
        img_path = os.path.join(test_dir, img_file)
        segmented_image = segment_image(img_path)
        
        output_img = Image.fromarray(segmented_image)
        output_img.save(os.path.join(output_dir, img_file))  

test_dir = '/kaggle/input/iitg-ai-overnight-hackathon-2024/dataset/dataset/test'
output_dir = '/kaggle/working/high_quality_segment'

# List of test images 
test_images = [
    "frame0000_leftImg8bit.jpg", "frame0014_leftImg8bit.jpg", "frame0119_leftImg8bit.jpg",
    "frame0199_leftImg8bit.jpg", "frame0277_leftImg8bit.jpg", "frame0340_leftImg8bit.jpg",
    "frame0342_leftImg8bit.jpg", "frame0364_leftImg8bit.jpg", "frame0514_leftImg8bit.jpg",
    "frame0550_leftImg8bit.jpg", "frame0604_leftImg8bit.jpg", "frame0664_leftImg8bit.jpg",
    "frame0671_leftImg8bit.jpg", "frame0704_leftImg8bit.jpg", "frame0724_leftImg8bit.jpg",
    "frame0821_leftImg8bit.jpg", "frame0874_leftImg8bit.jpg", "frame0918_leftImg8bit.jpg",
    "frame0924_leftImg8bit.jpg", "frame0964_leftImg8bit.jpg", "frame0982_leftImg8bit.jpg",
    "frame1002_leftImg8bit.jpg", "frame1014_leftImg8bit.jpg", "frame10376_leftImg8bit.jpg",
    "frame1047_leftImg8bit.jpg", "frame10676_leftImg8bit.jpg", "frame10758_leftImg8bit.jpg",
    "frame1084_leftImg8bit.jpg", "frame11003_leftImg8bit.jpg", "frame11630_leftImg8bit.jpg",
    "frame1174_leftImg8bit.jpg", "frame12146_leftImg8bit.jpg", "frame1227_leftImg8bit.jpg",
    "frame1263_leftImg8bit.jpg", "frame1347_leftImg8bit.jpg", "frame1348_leftImg8bit.jpg",
    "frame1356_leftImg8bit.jpg", "frame1384_leftImg8bit.jpg", "frame1393_leftImg8bit.jpg",
    "frame1428_leftImg8bit.jpg", "frame1518_leftImg8bit.jpg", "frame1527_leftImg8bit.jpg",
    "frame1534_leftImg8bit.jpg", "frame1565_leftImg8bit.jpg", "frame1591_leftImg8bit.jpg",
    "frame1630_leftImg8bit.jpg", "frame1647_leftImg8bit.jpg", "frame1654_leftImg8bit.jpg",
    "frame1793_leftImg8bit.jpg", "frame1833_leftImg8bit.jpg", "frame1848_leftImg8bit.jpg",
    "frame1866_leftImg8bit.jpg", "frame1878_leftImg8bit.jpg", "frame1898_leftImg8bit.jpg",
    "frame1900_leftImg8bit.jpg", "frame1918_leftImg8bit.jpg", "frame2014_leftImg8bit.jpg",
    "frame2043_leftImg8bit.jpg", "frame2046_leftImg8bit.jpg", "frame2058_leftImg8bit.jpg",
    "frame2063_leftImg8bit.jpg", "frame2132_leftImg8bit.jpg", "frame2193_leftImg8bit.jpg",
    "frame2293_leftImg8bit.jpg", "frame2314_leftImg8bit.jpg", "frame2423_leftImg8bit.jpg",
    "frame2528_leftImg8bit.jpg", "frame2584_leftImg8bit.jpg", "frame2598_leftImg8bit.jpg",
    "frame2796_leftImg8bit.jpg", "frame2824_leftImg8bit.jpg", "frame2838_leftImg8bit.jpg",
    "frame2944_leftImg8bit.jpg", "frame2949_leftImg8bit.jpg", "frame2976_leftImg8bit.jpg",
    "frame2993_leftImg8bit.jpg", "frame3048_leftImg8bit.jpg", "frame3094_leftImg8bit.jpg",
    "frame3134_leftImg8bit.jpg", "frame3263_leftImg8bit.jpg", "frame3276_leftImg8bit.jpg",
    "frame3334_leftImg8bit.jpg", "frame3348_leftImg8bit.jpg", "frame3486_leftImg8bit.jpg",
    "frame3532_leftImg8bit.jpg", "frame3592_leftImg8bit.jpg", "frame3618_leftImg8bit.jpg",
    "frame3691_leftImg8bit.jpg", "frame3724_leftImg8bit.jpg", "frame3828_leftImg8bit.jpg",
    "frame3862_leftImg8bit.jpg", "frame3966_leftImg8bit.jpg", "frame3967_leftImg8bit.jpg",
    "frame4043_leftImg8bit.jpg", "frame4266_leftImg8bit.jpg", "frame4283_leftImg8bit.jpg",
    "frame4428_leftImg8bit.jpg", "frame4566_leftImg8bit.jpg", "frame4763_leftImg8bit.jpg",
    "frame4986_leftImg8bit.jpg", "frame5153_leftImg8bit.jpg", "frame5196_leftImg8bit.jpg",
    "frame5393_leftImg8bit.jpg", "frame5406_leftImg8bit.jpg", "frame5573_leftImg8bit.jpg",
    "frame5586_leftImg8bit.jpg", "frame5783_leftImg8bit.jpg", "frame6009_leftImg8bit.jpg",
    "frame6216_leftImg8bit.jpg", "frame6396_leftImg8bit.jpg", "frame6473_leftImg8bit.jpg",
    "frame6893_leftImg8bit.jpg", "frame6966_leftImg8bit.jpg", "frame7283_leftImg8bit.jpg",
    "frame7433_leftImg8bit.jpg", "frame7446_leftImg8bit.jpg", "frame8826_leftImg8bit.jpg",
    "frame9426_leftImg8bit.jpg"]

process_test_images(test_images, test_dir, output_dir)
# Out:
# 100%|██████████| 118/118 [02:35<00:00,  1.31s/it]

# %%
import cv2
import numpy as np
import pandas as pd
import json
import os
import re  

class Label:
    def __init__(self, name, color):
        self.name = name
        self.color = color

labels = [
    Label('road', (128, 64, 128)),
    Label('sidewalk', (244, 35, 232)),
    Label('building', (70, 70, 70)),
    Label('wall', (102, 102, 156)),
    Label('fence', (190, 153, 153)),
    Label('pole', (153, 153, 153)),
    Label('traffic light', (250, 170, 30)),
    Label('traffic sign', (220, 220, 0)),
    Label('vegetation', (107, 142, 35)),
    Label('terrain', (152, 251, 152)),
    Label('sky', (70, 130, 180)),
    Label('person', (220, 20, 60)),
    Label('rider', (255, 0, 0)),
    Label('car', (0, 0, 142)),
    Label('truck', (0, 0, 70)),
    Label('bus', (0, 60, 100)),
    Label('train', (0, 80, 100)),
    Label('motorcycle', (0, 0, 230)),
    Label('bicycle', (119, 11, 32))
]

# extract polygons from a binary mask
def extract_polygons(mask):
    gray = cv2.cvtColor(mask, cv2.COLOR_BGR2GRAY) if len(mask.shape) == 3 else mask
    contours, _ = cv2.findContours(gray, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    polygons = []
    for contour in contours:
        epsilon = 0.01 * cv2.arcLength(contour, True)
        approx = cv2.approxPolyDP(contour, epsilon, True)
        polygon = approx.reshape(-1, 2).tolist()
        polygons.append(polygon)
    return polygons

# map colors to labels and extract polygons
def convert_mask_to_objects(mask):
    objects = []
    for label in labels:
        mask_label = cv2.inRange(mask, np.array(label.color), np.array(label.color))
        polygons = extract_polygons(mask_label)
        for polygon in polygons:
            objects.append({"label": label.name, "polygon": polygon})
    return objects

# saving to csv
def process_masks(mask_dir, output_csv):
    data = []
    print(f"Processing directory: {mask_dir}")

    mask_files = [f for f in os.listdir(mask_dir) if f.endswith(".jpg")]
    mask_files.sort(key=lambda x: int(re.search(r'(\d+)', x).group()))  

    for mask_file in mask_files:
        mask_path = os.path.join(mask_dir, mask_file)
        print(f"Processing file: {mask_path}")
        mask = cv2.imread(mask_path)

        if mask is None:
            print(f"Error reading file: {mask_path}")
            continue 

        frame_id = os.path.splitext(mask_file)[0]
        objects = convert_mask_to_objects(mask)
        if objects:
            print(f"Objects found for frame {frame_id}: {objects}")
        else:
            print(f"No objects found for frame {frame_id}")
        data.append({"id": frame_id, "objects": json.dumps(objects)})

    if data:
        df = pd.DataFrame(data, columns=["id", "objects"])
        df.to_csv(output_csv, index=False)
        print(f"CSV file saved at: {output_csv}")
    else:
        print("No data to save to CSV.")


mask_dir = "/kaggle/working/high_quality_segment"
output_csv = "/kaggle/working/segmentation_output.csv"
process_masks(mask_dir, output_csv)

print("Processing completed.")
# Out:
# Processing directory: /kaggle/working/high_quality_segment
# Processing file: /kaggle/working/high_quality_segment/frame0000_leftImg8bit.jpg
# No objects found for frame frame0000_leftImg8bit
# Processing file: /kaggle/working/high_quality_segment/frame0014_leftImg8bit.jpg
# No objects found for frame frame0014_leftImg8bit
# Processing file: /kaggle/working/high_quality_segment/frame0119_leftImg8bit.jpg
# No objects found for frame frame0119_leftImg8bit
# Processing file: /kaggle/working/high_quality_segment/frame0199_leftImg8bit.jpg
# No objects found for frame frame0199_leftImg8bit
# Processing file: /kaggle/working/high_quality_segment/frame0277_leftImg8bit.jpg
# No objects found for frame frame0277_leftImg8bit
# Processing file: /kaggle/working/high_quality_segment/frame0340_leftImg8bit.jpg
# No objects found for frame frame0340_leftImg8bit
# Processing file: /kaggle/working/high_quality_segment/frame0342_leftImg8bit.jpg
# No objects found for frame frame0342_leftImg8bit
# Processing file: /kaggle/working/high_quality_segment/frame0364_leftImg8bit.jpg
# No objects found for frame frame0364_leftImg8bit
# Processing file: /kaggle/working/high_quality_segment/frame0514_leftImg8bit.jpg
# No objects found for frame frame0514_leftImg8bit
# Processing file: /kaggle/working/high_quality_segment/frame0550_leftImg8bit.jpg
# No objects found for frame frame0550_leftImg8bit
# Processing file: /kaggle/working/high_quality_segment/frame0604_leftImg8bit.jpg
# No objects found for frame frame0604_leftImg8bit
# Processing file: /kaggle/working/high_quality_segment/frame0664_leftImg8bit.jpg
# No objects found for frame frame0664_leftImg8bit
# Processing file: /kaggle/working/high_quality_segment/frame0671_leftImg8bit.jpg
# No objects found for frame frame0671_leftImg8bit
# Processing file: /kaggle/working/high_quality_segment/frame0704_leftImg8bit.jpg
# No objects found for frame frame0704_leftImg8bit
# Processing file: /kaggle/working/high_quality_segment/frame0724_leftImg8bit.jpg
# No objects found for frame frame0724_leftImg8bit
# Processing file: /kaggle/working/high_quality_segment/frame0821_leftImg8bit.jpg
# No objects found for frame frame0821_leftImg8bit
# Processing file: /kaggle/working/high_quality_segment/frame0874_leftImg8bit.jpg
# No objects found for frame frame0874_leftImg8bit
# Processing file: /kaggle/working/high_quality_segment/frame0918_leftImg8bit.jpg
# No objects found for frame frame0918_leftImg8bit
# Processing file: /kaggle/working/high_quality_segment/frame0924_leftImg8bit.jpg
# No objects found for frame frame0924_leftImg8bit
# Processing file: /kaggle/working/high_quality_segment/frame0964_leftImg8bit.jpg
# No objects found for frame frame0964_leftImg8bit
# Processing file: /kaggle/working/high_quality_segment/frame0982_leftImg8bit.jpg
# No objects found for frame frame0982_leftImg8bit
# Processing file: /kaggle/working/high_quality_segment/frame1002_leftImg8bit.jpg
# No objects found for frame frame1002_leftImg8bit
# Processing file: /kaggle/working/high_quality_segment/frame1014_leftImg8bit.jpg
# Objects found for frame frame1014_leftImg8bit: [{'label': 'pole', 'polygon': [[220, 493]]}, {'label': 'pole', 'polygon': [[212, 491]]}, {'label': 'pole', 'polygon': [[188, 491]]}, {'label': 'pole', 'polygon': [[228, 490]]}, {'label': 'pole', 'polygon': [[221, 490], [222, 491]]}, {'label': 'pole', 'polygon': [[215, 489]]}, {'label': 'pole', 'polygon': [[183, 488]]}, {'label': 'pole', 'polygon': [[189, 484]]}, {'label': 'pole', 'polygon': [[178, 479], [180, 479]]}, {'label': 'pole', 'polygon': [[244, 477]]}, {'label': 'pole', 'polygon': [[239, 476], [239, 477]]}, {'label': 'pole', 'polygon': [[234, 476]]}, {'label': 'pole', 'polygon': [[179, 475]]}, {'label': 'pole', 'polygon': [[233, 473]]}, {'label': 'pole', 'polygon': [[183, 480], [199, 479], [200, 487], [223, 488], [223, 480], [231, 479], [231, 472], [184, 472]]}]
# Processing file: /kaggle/working/high_quality_segment/frame1047_leftImg8bit.jpg
# No objects found for frame frame1047_leftImg8bit
# Processing file: /kaggle/working/high_quality_segment/frame1084_leftImg8bit.jpg
# Objects found for frame frame1084_leftImg8bit: [{'label': 'truck', 'polygon': [[60, 881]]}, {'label': 'truck', 'polygon': [[153, 861]]}, {'label': 'truck', 'polygon': [[64, 835]]}, {'label': 'truck', 'polygon': [[77, 808]]}]
# Processing file: /kaggle/working/high_quality_segment/frame1174_leftImg8bit.jpg
# No objects found for frame frame1174_leftImg8bit
# Processing file: /kaggle/working/high_quality_segment/frame1227_leftImg8bit.jpg
# No objects found for frame frame1227_leftImg8bit
# Processing file: /kaggle/working/high_quality_segment/frame1263_leftImg8bit.jpg
# No objects found for frame frame1263_leftImg8bit
# Processing file: /kaggle/working/high_quality_segment/frame1347_leftImg8bit.jpg
# No objects found for frame frame1347_leftImg8bit
# Processing file: /kaggle/working/high_quality_segment/frame1348_leftImg8bit.jpg
# No objects found for frame frame1348_leftImg8bit
# Processing file: /kaggle/working/high_quality_segment/frame1356_leftImg8bit.jpg
# No objects found for frame frame1356_leftImg8bit
# Processing file: /kaggle/working/high_quality_segment/frame1384_leftImg8bit.jpg
# Objects found for frame frame1384_leftImg8bit: [{'label': 'building', 'polygon': [[411, 772], [412, 772]]}]
# Processing file: /kaggle/working/high_quality_segment/frame1393_leftImg8bit.jpg
# No objects found for frame frame1393_leftImg8bit
# Processing file: /kaggle/working/high_quality_segment/frame1428_leftImg8bit.jpg
# No objects found for frame frame1428_leftImg8bit
# Processing file: /kaggle/working/high_quality_segment/frame1518_leftImg8bit.jpg
# No objects found for frame frame1518_leftImg8bit
# Processing file: /kaggle/working/high_quality_segment/frame1527_leftImg8bit.jpg
# No objects found for frame frame1527_leftImg8bit
# Processing file: /kaggle/working/high_quality_segment/frame1534_leftImg8bit.jpg
# No objects found for frame frame1534_leftImg8bit
# Processing file: /kaggle/working/high_quality_segment/frame1565_leftImg8bit.jpg
# No objects found for frame frame1565_leftImg8bit
# Processing file: /kaggle/working/high_quality_segment/frame1591_leftImg8bit.jpg
# Objects found for frame frame1591_leftImg8bit: [{'label': 'pole', 'polygon': [[954, 525]]}, {'label': 'pole', 'polygon': [[947, 525]]}, {'label': 'pole', 'polygon': [[988, 524]]}, {'label': 'pole', 'polygon': [[980, 523]]}, {'label': 'pole', 'polygon': [[954, 523]]}, {'label': 'pole', 'polygon': [[957, 522]]}, {'label': 'pole', 'polygon': [[946, 522], [945, 523]]}, {'label': 'pole', 'polygon': [[983, 521]]}, {'label': 'pole', 'polygon': [[938, 521], [939, 521]]}, {'label': 'pole', 'polygon': [[941, 512], [941, 519]]}, {'label': 'pole', 'polygon': [[941, 498]]}, {'label': 'pole', 'polygon': [[996, 492]]}, {'label': 'pole', 'polygon': [[996, 490]]}, {'label': 'pole', 'polygon': [[994, 489]]}, {'label': 'pole', 'polygon': [[940, 486]]}, {'label': 'pole', 'polygon': [[942, 482]]}, {'label': 'pole', 'polygon': [[994, 480]]}, {'label': 'pole', 'polygon': [[987, 478]]}, {'label': 'pole', 'polygon': [[976, 478]]}, {'label': 'pole', 'polygon': [[970, 477]]}, {'label': 'pole', 'polygon': [[993, 476]]}, {'label': 'pole', 'polygon': [[988, 476]]}, {'label': 'pole', 'polygon': [[979, 476]]}, {'label': 'pole', 'polygon': [[950, 476]]}, {'label': 'pole', 'polygon': [[970, 474]]}, {'label': 'pole', 'polygon': [[947, 474]]}, {'label': 'pole', 'polygon': [[952, 472], [952, 478], [944, 480], [944, 520], [991, 519], [992, 480], [970, 480], [967, 478], [967, 472]]}, {'label': 'pole', 'polygon': [[950, 472]]}]
# Processing file: /kaggle/working/high_quality_segment/frame1630_leftImg8bit.jpg
# No objects found for frame frame1630_leftImg8bit
# Processing file: /kaggle/working/high_quality_segment/frame1647_leftImg8bit.jpg
# No objects found for frame frame1647_leftImg8bit
# Processing file: /kaggle/working/high_quality_segment/frame1654_leftImg8bit.jpg
# No objects found for frame frame1654_leftImg8bit
# Processing file: /kaggle/working/high_quality_segment/frame1793_leftImg8bit.jpg
# No objects found for frame frame1793_leftImg8bit
# Processing file: /kaggle/working/high_quality_segment/frame1833_leftImg8bit.jpg
# No objects found for frame frame1833_leftImg8bit
# Processing file: /kaggle/working/high_quality_segment/frame1848_leftImg8bit.jpg
# Objects found for frame frame1848_leftImg8bit: [{'label': 'building', 'polygon': [[351, 1011], [351, 1012]]}, {'label': 'building', 'polygon': [[308, 887]]}, {'label': 'building', 'polygon': [[309, 885]]}, {'label': 'building', 'polygon': [[312, 884]]}, {'label': 'building', 'polygon': [[283, 884], [284, 885], [284, 886], [284, 885]]}, {'label': 'building', 'polygon': [[280, 884]]}, {'label': 'building', 'polygon': [[310, 883]]}, {'label': 'building', 'polygon': [[315, 882]]}, {'label': 'building', 'polygon': [[283, 882]]}, {'label': 'building', 'polygon': [[285, 881]]}, {'label': 'building', 'polygon': [[223, 878], [224, 878]]}, {'label': 'building', 'polygon': [[226, 877]]}, {'label': 'building', 'polygon': [[221, 877]]}, {'label': 'building', 'polygon': [[248, 876], [263, 876]]}, {'label': 'building', 'polygon': [[265, 874]]}, {'label': 'building', 'polygon': [[231, 874], [239, 874]]}, {'label': 'building', 'polygon': [[225, 874]]}, {'label': 'building', 'polygon': [[222, 874]]}, {'label': 'building', 'polygon': [[215, 873], [216, 874]]}, {'label': 'building', 'polygon': [[321, 869]]}, {'label': 'building', 'polygon': [[324, 867]]}, {'label': 'building', 'polygon': [[321, 867]]}, {'label': 'building', 'polygon': [[206, 866], [206, 867]]}, {'label': 'building', 'polygon': [[324, 863]]}, {'label': 'building', 'polygon': [[213, 862]]}, {'label': 'building', 'polygon': [[206, 862]]}, {'label': 'building', 'polygon': [[325, 861]]}, {'label': 'building', 'polygon': [[211, 861]]}, {'label': 'building', 'polygon': [[326, 859]]}, {'label': 'building', 'polygon': [[208, 859]]}, {'label': 'building', 'polygon': [[212, 857], [212, 858], [211, 859], [212, 858]]}, {'label': 'building', 'polygon': [[323, 856], [324, 856]]}, {'label': 'building', 'polygon': [[326, 855]]}, {'label': 'building', 'polygon': [[326, 853]]}, {'label': 'building', 'polygon': [[324, 849]]}, {'label': 'building', 'polygon': [[308, 846]]}, {'label': 'building', 'polygon': [[232, 846]]}, {'label': 'building', 'polygon': [[208, 864], [209, 872], [271, 871], [272, 879], [287, 879], [287, 887], [296, 888], [288, 889], [299, 889], [304, 879], [319, 879], [321, 860], [319, 848], [311, 847], [319, 846], [240, 845], [287, 847], [224, 848], [224, 855], [214, 855], [216, 863]]}, {'label': 'building', 'polygon': [[234, 845]]}, {'label': 'building', 'polygon': [[303, 844]]}, {'label': 'building', 'polygon': [[297, 844]]}]
# Processing file: /kaggle/working/high_quality_segment/frame1866_leftImg8bit.jpg
# Objects found for frame frame1866_leftImg8bit: [{'label': 'pole', 'polygon': [[911, 580], [912, 580]]}, {'label': 'pole', 'polygon': [[918, 579]]}, {'label': 'pole', 'polygon': [[905, 579]]}, {'label': 'pole', 'polygon': [[921, 576]]}, {'label': 'pole', 'polygon': [[891, 574]]}, {'label': 'pole', 'polygon': [[836, 574]]}, {'label': 'pole', 'polygon': [[883, 573]]}, {'label': 'pole', 'polygon': [[819, 573]]}, {'label': 'pole', 'polygon': [[817, 572]]}, {'label': 'pole', 'polygon': [[870, 571]]}, {'label': 'pole', 'polygon': [[846, 571]]}, {'label': 'pole', 'polygon': [[882, 570], [881, 571]]}, {'label': 'pole', 'polygon': [[844, 570]]}, {'label': 'pole', 'polygon': [[817, 570]]}, {'label': 'pole', 'polygon': [[894, 569], [893, 570]]}, {'label': 'pole', 'polygon': [[859, 569]]}, {'label': 'pole', 'polygon': [[833, 569], [834, 570]]}, {'label': 'pole', 'polygon': [[813, 565]]}, {'label': 'pole', 'polygon': [[813, 562]]}, {'label': 'pole', 'polygon': [[803, 556]]}, {'label': 'pole', 'polygon': [[805, 544], [805, 551]]}, {'label': 'pole', 'polygon': [[804, 542]]}, {'label': 'pole', 'polygon': [[806, 541], [806, 542]]}, {'label': 'pole', 'polygon': [[930, 538]]}, {'label': 'pole', 'polygon': [[923, 524], [923, 525]]}, {'label': 'pole', 'polygon': [[925, 523]]}, {'label': 'pole', 'polygon': [[922, 516]]}, {'label': 'pole', 'polygon': [[924, 515], [924, 516]]}, {'label': 'pole', 'polygon': [[805, 510]]}, {'label': 'pole', 'polygon': [[801, 506]]}, {'label': 'pole', 'polygon': [[804, 505], [805, 506]]}, {'label': 'pole', 'polygon': [[803, 499], [803, 500]]}, {'label': 'pole', 'polygon': [[805, 496]]}, {'label': 'pole', 'polygon': [[921, 494]]}, {'label': 'pole', 'polygon': [[923, 492]]}, {'label': 'pole', 'polygon': [[805, 489]]}, {'label': 'pole', 'polygon': [[924, 484]]}, {'label': 'pole', 'polygon': [[805, 482]]}, {'label': 'pole', 'polygon': [[885, 470]]}, {'label': 'pole', 'polygon': [[907, 469], [907, 470]]}, {'label': 'pole', 'polygon': [[891, 469], [891, 470]]}, {'label': 'pole', 'polygon': [[872, 469], [879, 469]]}, {'label': 'pole', 'polygon': [[869, 469]]}, {'label': 'pole', 'polygon': [[814, 469]]}, {'label': 'pole', 'polygon': [[910, 468]]}, {'label': 'pole', 'polygon': [[896, 468]]}, {'label': 'pole', 'polygon': [[894, 468]]}, {'label': 'pole', 'polygon': [[865, 468]]}, {'label': 'pole', 'polygon': [[817, 468]]}, {'label': 'pole', 'polygon': [[826, 467], [827, 468]]}, {'label': 'pole', 'polygon': [[871, 465]]}, {'label': 'pole', 'polygon': [[864, 465]]}, {'label': 'pole', 'polygon': [[823, 465]]}, {'label': 'pole', 'polygon': [[808, 472], [808, 511], [800, 511], [800, 519], [806, 520], [807, 560], [823, 567], [823, 575], [832, 575], [832, 567], [895, 567], [895, 575], [927, 568], [919, 472], [864, 472], [855, 464]]}]
# Processing file: /kaggle/working/high_quality_segment/frame1878_leftImg8bit.jpg
# No objects found for frame frame1878_leftImg8bit
# Processing file: /kaggle/working/high_quality_segment/frame1898_leftImg8bit.jpg
# No objects found for frame frame1898_leftImg8bit
# Processing file: /kaggle/working/high_quality_segment/frame1900_leftImg8bit.jpg
# No objects found for frame frame1900_leftImg8bit
# Processing file: /kaggle/working/high_quality_segment/frame1918_leftImg8bit.jpg
# No objects found for frame frame1918_leftImg8bit
# Processing file: /kaggle/working/high_quality_segment/frame2014_leftImg8bit.jpg
# No objects found for frame frame2014_leftImg8bit
# Processing file: /kaggle/working/high_quality_segment/frame2043_leftImg8bit.jpg
# No objects found for frame frame2043_leftImg8bit
# Processing file: /kaggle/working/high_quality_segment/frame2046_leftImg8bit.jpg
# Objects found for frame frame2046_leftImg8bit: [{'label': 'pole', 'polygon': [[1492, 661]]}, {'label': 'pole', 'polygon': [[1502, 659]]}, {'label': 'pole', 'polygon': [[1507, 657]]}, {'label': 'pole', 'polygon': [[1485, 653]]}, {'label': 'pole', 'polygon': [[1523, 648]]}, {'label': 'pole', 'polygon': [[1523, 646], [1524, 646]]}, {'label': 'pole', 'polygon': [[1482, 642]]}, {'label': 'pole', 'polygon': [[1476, 634]]}, {'label': 'pole', 'polygon': [[974, 632]]}, {'label': 'pole', 'polygon': [[971, 631]]}, {'label': 'pole', 'polygon': [[1506, 629]]}, {'label': 'pole', 'polygon': [[1475, 629], [1477, 629]]}, {'label': 'pole', 'polygon': [[1506, 626]]}, {'label': 'pole', 'polygon': [[1478, 626]]}, {'label': 'pole', 'polygon': [[1185, 626]]}, {'label': 'pole', 'polygon': [[1189, 625]]}, {'label': 'pole', 'polygon': [[966, 624]]}, {'label': 'pole', 'polygon': [[1195, 623]]}, {'label': 'pole', 'polygon': [[994, 622]]}, {'label': 'pole', 'polygon': [[1000, 621]]}, {'label': 'pole', 'polygon': [[1001, 619]]}, {'label': 'pole', 'polygon': [[1197, 618]]}, {'label': 'pole', 'polygon': [[1128, 618]]}, {'label': 'pole', 'polygon': [[1121, 618]]}, {'label': 'pole', 'polygon': [[1118, 618]]}, {'label': 'pole', 'polygon': [[1014, 618]]}, {'label': 'pole', 'polygon': [[1126, 617]]}, {'label': 'pole', 'polygon': [[1104, 617], [1112, 617]]}, {'label': 'pole', 'polygon': [[963, 617]]}, {'label': 'pole', 'polygon': [[1506, 616]]}, {'label': 'pole', 'polygon': [[1477, 616], [1477, 623]]}, {'label': 'pole', 'polygon': [[1201, 616]]}, {'label': 'pole', 'polygon': [[936, 613]]}, {'label': 'pole', 'polygon': [[1506, 612]]}, {'label': 'pole', 'polygon': [[1508, 611], [1508, 612]]}, {'label': 'pole', 'polygon': [[1204, 611]]}, {'label': 'pole', 'polygon': [[942, 610]]}, {'label': 'pole', 'polygon': [[930, 610]]}, {'label': 'pole', 'polygon': [[1209, 608]]}, {'label': 'pole', 'polygon': [[1508, 607]]}, {'label': 'pole', 'polygon': [[925, 605]]}, {'label': 'pole', 'polygon': [[1478, 603]]}, {'label': 'pole', 'polygon': [[916, 603]]}, {'label': 'pole', 'polygon': [[925, 602]]}, {'label': 'pole', 'polygon': [[1508, 601]]}, {'label': 'pole', 'polygon': [[1475, 600]]}, {'label': 'pole', 'polygon': [[1575, 599]]}, {'label': 'pole', 'polygon': [[1573, 599]]}, {'label': 'pole', 'polygon': [[916, 598]]}, {'label': 'pole', 'polygon': [[1588, 597]]}, {'label': 'pole', 'polygon': [[918, 597], [918, 598]]}, {'label': 'pole', 'polygon': [[1581, 596]]}, {'label': 'pole', 'polygon': [[1578, 596]]}, {'label': 'pole', 'polygon': [[1585, 595]]}, {'label': 'pole', 'polygon': [[1477, 594]]}, {'label': 'pole', 'polygon': [[1225, 594]]}, {'label': 'pole', 'polygon': [[1583, 593]]}, {'label': 'pole', 'polygon': [[1576, 593]]}, {'label': 'pole', 'polygon': [[1586, 591]]}, {'label': 'pole', 'polygon': [[1574, 591], [1575, 591]]}, {'label': 'pole', 'polygon': [[1508, 591]]}, {'label': 'pole', 'polygon': [[917, 590], [918, 591]]}, {'label': 'pole', 'polygon': [[1581, 589]]}, {'label': 'pole', 'polygon': [[1479, 588]]}, {'label': 'pole', 'polygon': [[1508, 587]]}, {'label': 'pole', 'polygon': [[1585, 586]]}, {'label': 'pole', 'polygon': [[1583, 586]]}, {'label': 'pole', 'polygon': [[1500, 582]]}, {'label': 'pole', 'polygon': [[1501, 580]]}, {'label': 'pole', 'polygon': [[1498, 579]]}, {'label': 'pole', 'polygon': [[916, 578]]}, {'label': 'pole', 'polygon': [[1234, 576]]}, {'label': 'pole', 'polygon': [[1588, 575]]}, {'label': 'pole', 'polygon': [[1498, 575]]}, {'label': 'pole', 'polygon': [[916, 575]]}, {'label': 'pole', 'polygon': [[1500, 574]]}, {'label': 'pole', 'polygon': [[1590, 569]]}, {'label': 'pole', 'polygon': [[1540, 566]]}, {'label': 'pole', 'polygon': [[1535, 565]]}, {'label': 'pole', 'polygon': [[1234, 565]]}, {'label': 'pole', 'polygon': [[1532, 564]]}, {'label': 'pole', 'polygon': [[1596, 562]]}, {'label': 'pole', 'polygon': [[1234, 562]]}, {'label': 'pole', 'polygon': [[1537, 561]]}, {'label': 'pole', 'polygon': [[1523, 561]]}, {'label': 'pole', 'polygon': [[1604, 559] ...
# Processing file: /kaggle/working/high_quality_segment/frame2058_leftImg8bit.jpg
# No objects found for frame frame2058_leftImg8bit
# Processing file: /kaggle/working/high_quality_segment/frame2063_leftImg8bit.jpg
# No objects found for frame frame2063_leftImg8bit
# Processing file: /kaggle/working/high_quality_segment/frame2132_leftImg8bit.jpg
# No objects found for frame frame2132_leftImg8bit
# Processing file: /kaggle/working/high_quality_segment/frame2193_leftImg8bit.jpg
# No objects found for frame frame2193_leftImg8bit
# Processing file: /kaggle/working/high_quality_segment/frame2293_leftImg8bit.jpg
# No objects found for frame frame2293_leftImg8bit
# Processing file: /kaggle/working/high_quality_segment/frame2314_leftImg8bit.jpg
# No objects found for frame frame2314_leftImg8bit
# Processing file: /kaggle/working/high_quality_segment/frame2423_leftImg8bit.jpg
# No objects found for frame frame2423_leftImg8bit
# Processing file: /kaggle/working/high_quality_segment/frame2528_leftImg8bit.jpg
# No objects found for frame frame2528_leftImg8bit
# Processing file: /kaggle/working/high_quality_segment/frame2584_leftImg8bit.jpg
# No objects found for frame frame2584_leftImg8bit
# Processing file: /kaggle/working/high_quality_segment/frame2598_leftImg8bit.jpg
# No objects found for frame frame2598_leftImg8bit
# Processing file: /kaggle/working/high_quality_segment/frame2796_leftImg8bit.jpg
# Objects found for frame frame2796_leftImg8bit: [{'label': 'pole', 'polygon': [[1334, 567]]}, {'label': 'pole', 'polygon': [[1329, 567]]}, {'label': 'pole', 'polygon': [[1336, 565]]}, {'label': 'pole', 'polygon': [[1339, 563]]}, {'label': 'pole', 'polygon': [[1334, 563]]}, {'label': 'pole', 'polygon': [[1329, 563]]}, {'label': 'pole', 'polygon': [[1325, 558]]}, {'label': 'pole', 'polygon': [[1357, 556]]}, {'label': 'pole', 'polygon': [[1362, 534]]}, {'label': 'pole', 'polygon': [[1361, 530]]}, {'label': 'pole', 'polygon': [[1365, 529]]}, {'label': 'pole', 'polygon': [[1378, 514]]}, {'label': 'pole', 'polygon': [[1391, 509]]}, {'label': 'pole', 'polygon': [[1317, 507], [1317, 508]]}, {'label': 'pole', 'polygon': [[1385, 506]]}, {'label': 'pole', 'polygon': [[1396, 505]]}, {'label': 'pole', 'polygon': [[1394, 505]]}, {'label': 'pole', 'polygon': [[1403, 503]]}, {'label': 'pole', 'polygon': [[1411, 496]]}, {'label': 'pole', 'polygon': [[1406, 496]]}, {'label': 'pole', 'polygon': [[1409, 492], [1410, 493]]}, {'label': 'pole', 'polygon': [[1412, 491]]}, {'label': 'pole', 'polygon': [[1405, 491], [1404, 492]]}, {'label': 'pole', 'polygon': [[1324, 491]]}, {'label': 'pole', 'polygon': [[1326, 489]]}, {'label': 'pole', 'polygon': [[1323, 484]]}, {'label': 'pole', 'polygon': [[1324, 482]]}, {'label': 'pole', 'polygon': [[1408, 473]]}, {'label': 'pole', 'polygon': [[1352, 470]]}, {'label': 'pole', 'polygon': [[1348, 470]]}, {'label': 'pole', 'polygon': [[1395, 469]]}, {'label': 'pole', 'polygon': [[1386, 469], [1385, 470]]}, {'label': 'pole', 'polygon': [[1357, 469], [1358, 470]]}, {'label': 'pole', 'polygon': [[1397, 468]]}, {'label': 'pole', 'polygon': [[1340, 468]]}, {'label': 'pole', 'polygon': [[1363, 467]]}, {'label': 'pole', 'polygon': [[1396, 466]]}, {'label': 'pole', 'polygon': [[1354, 466]]}, {'label': 'pole', 'polygon': [[1388, 465]]}, {'label': 'pole', 'polygon': [[1399, 472], [1384, 472], [1384, 464], [1368, 464], [1367, 472], [1336, 472], [1336, 479], [1328, 480], [1328, 495], [1320, 496], [1319, 544], [1320, 551], [1328, 552], [1327, 560], [1351, 559], [1351, 553], [1359, 551], [1359, 528], [1367, 527], [1376, 511], [1383, 512], [1384, 503], [1399, 503]]}]
# Processing file: /kaggle/working/high_quality_segment/frame2824_leftImg8bit.jpg
# No objects found for frame frame2824_leftImg8bit
# Processing file: /kaggle/working/high_quality_segment/frame2838_leftImg8bit.jpg
# Objects found for frame frame2838_leftImg8bit: [{'label': 'pole', 'polygon': [[1878, 444]]}, {'label': 'pole', 'polygon': [[1884, 441]]}, {'label': 'pole', 'polygon': [[1882, 441]]}, {'label': 'pole', 'polygon': [[1875, 440]]}, {'label': 'pole', 'polygon': [[1880, 439], [1881, 439]]}]
# Processing file: /kaggle/working/high_quality_segment/frame2944_leftImg8bit.jpg
# No objects found for frame frame2944_leftImg8bit
# Processing file: /kaggle/working/high_quality_segment/frame2949_leftImg8bit.jpg
# Objects found for frame frame2949_leftImg8bit: [{'label': 'pole', 'polygon': [[2037, 684]]}, {'label': 'pole', 'polygon': [[2040, 556]]}, {'label': 'pole', 'polygon': [[1979, 555], [1979, 556], [1980, 556], [1980, 555]]}]
# Processing file: /kaggle/working/high_quality_segment/frame2976_leftImg8bit.jpg
# Objects found for frame frame2976_leftImg8bit: [{'label': 'building', 'polygon': [[281, 706], [281, 707]]}, {'label': 'building', 'polygon': [[262, 705], [261, 706], [262, 707], [261, 706]]}, {'label': 'building', 'polygon': [[282, 704], [283, 704]]}, {'label': 'building', 'polygon': [[264, 704], [264, 711], [271, 711], [271, 704]]}, {'label': 'building', 'polygon': [[271, 702]]}, {'label': 'building', 'polygon': [[281, 700]]}, {'label': 'pole', 'polygon': [[2026, 682]]}, {'label': 'pole', 'polygon': [[1955, 678]]}, {'label': 'pole', 'polygon': [[1771, 677]]}, {'label': 'pole', 'polygon': [[1788, 676]]}, {'label': 'pole', 'polygon': [[1952, 674]]}, {'label': 'pole', 'polygon': [[1949, 674]]}, {'label': 'pole', 'polygon': [[1776, 674], [1783, 674]]}, {'label': 'pole', 'polygon': [[1770, 674], [1769, 675]]}, {'label': 'pole', 'polygon': [[1969, 673], [1969, 674], [1970, 674]]}, {'label': 'pole', 'polygon': [[1802, 669]]}, {'label': 'pole', 'polygon': [[1812, 668]]}, {'label': 'pole', 'polygon': [[1916, 667]]}, {'label': 'pole', 'polygon': [[1820, 667]]}, {'label': 'pole', 'polygon': [[1751, 667]]}, {'label': 'pole', 'polygon': [[1832, 666], [1839, 666], [1840, 667], [1839, 666]]}, {'label': 'pole', 'polygon': [[1802, 666]]}, {'label': 'pole', 'polygon': [[1969, 665]]}, {'label': 'pole', 'polygon': [[1942, 665]]}, {'label': 'pole', 'polygon': [[1819, 665]]}, {'label': 'pole', 'polygon': [[1883, 662]]}, {'label': 'pole', 'polygon': [[1972, 661], [1973, 661]]}, {'label': 'pole', 'polygon': [[1965, 660]]}, {'label': 'pole', 'polygon': [[1869, 659], [1870, 660], [1871, 660], [1871, 659], [1872, 658], [1879, 658], [1872, 658], [1870, 660]]}, {'label': 'pole', 'polygon': [[1886, 657], [1885, 658]]}, {'label': 'pole', 'polygon': [[1865, 657]]}, {'label': 'pole', 'polygon': [[1747, 657]]}, {'label': 'pole', 'polygon': [[1749, 656], [1749, 657]]}, {'label': 'pole', 'polygon': [[1945, 637]]}, {'label': 'pole', 'polygon': [[1749, 636]]}, {'label': 'pole', 'polygon': [[1954, 630]]}, {'label': 'pole', 'polygon': [[1749, 629]]}, {'label': 'pole', 'polygon': [[1979, 627], [1978, 628]]}, {'label': 'pole', 'polygon': [[1970, 627], [1971, 627]]}, {'label': 'pole', 'polygon': [[1970, 624]]}, {'label': 'pole', 'polygon': [[1728, 619]]}, {'label': 'pole', 'polygon': [[1725, 619]]}, {'label': 'pole', 'polygon': [[1732, 618]]}, {'label': 'pole', 'polygon': [[1971, 617], [1972, 618], [1973, 617], [1972, 618]]}, {'label': 'pole', 'polygon': [[1965, 617]]}, {'label': 'pole', 'polygon': [[1718, 617], [1719, 618]]}, {'label': 'pole', 'polygon': [[1717, 613]]}, {'label': 'pole', 'polygon': [[1717, 610]]}, {'label': 'pole', 'polygon': [[1709, 605]]}, {'label': 'pole', 'polygon': [[1710, 599]]}, {'label': 'pole', 'polygon': [[1708, 598]]}, {'label': 'pole', 'polygon': [[1715, 564]]}, {'label': 'pole', 'polygon': [[1717, 544], [1717, 559]]}, {'label': 'pole', 'polygon': [[1717, 534], [1717, 535]]}, {'label': 'pole', 'polygon': [[1715, 534]]}, {'label': 'pole', 'polygon': [[1717, 518]]}, {'label': 'pole', 'polygon': [[1717, 497]]}, {'label': 'pole', 'polygon': [[1716, 494]]}, {'label': 'pole', 'polygon': [[1717, 472]]}, {'label': 'pole', 'polygon': [[1718, 468]]}, {'label': 'pole', 'polygon': [[1715, 466]]}, {'label': 'pole', 'polygon': [[1725, 453]]}, {'label': 'pole', 'polygon': [[1725, 450]]}, {'label': 'pole', 'polygon': [[1723, 444], [1723, 445]]}, {'label': 'pole', 'polygon': [[1726, 439]]}, {'label': 'pole', 'polygon': [[1723, 437]]}, {'label': 'pole', 'polygon': [[1724, 434]]}, {'label': 'pole', 'polygon': [[1733, 413]]}, {'label': 'pole', 'polygon': [[1733, 410]]}, {'label': 'pole', 'polygon': [[1733, 400], [1733, 401]]}, {'label': 'pole', 'polygon': [[1733, 392]]}, {'label': 'pole', 'polygon': [[1742, 380]]}, {'label': 'pole', 'polygon': [[1755, 371]]}, {'label': 'pole', 'polygon': [[1768, 365]]}, {'label': 'pole', 'polygon': [[1770, 363], [1770, 364]]}, {'label': 'pole', 'polygon': [[1798, 358]]}, {'label': 'pole', 'polygon': [[1805, 357]]}, {'label': ...
# Processing file: /kaggle/working/high_quality_segment/frame2993_leftImg8bit.jpg
# No objects found for frame frame2993_leftImg8bit
# Processing file: /kaggle/working/high_quality_segment/frame3048_leftImg8bit.jpg
# Objects found for frame frame3048_leftImg8bit: [{'label': 'building', 'polygon': [[311, 19]]}, {'label': 'building', 'polygon': [[308, 17]]}, {'label': 'building', 'polygon': [[188, 17]]}, {'label': 'building', 'polygon': [[316, 14]]}, {'label': 'building', 'polygon': [[311, 14]]}, {'label': 'building', 'polygon': [[308, 13]]}, {'label': 'building', 'polygon': [[181, 13]]}, {'label': 'building', 'polygon': [[179, 12], [179, 13]]}, {'label': 'building', 'polygon': [[308, 11]]}, {'label': 'building', 'polygon': [[186, 11]]}, {'label': 'building', 'polygon': [[318, 10]]}, {'label': 'building', 'polygon': [[182, 10]]}, {'label': 'building', 'polygon': [[321, 8]]}, {'label': 'building', 'polygon': [[181, 8]]}, {'label': 'building', 'polygon': [[309, 2], [309, 3], [309, 2], [310, 1], [311, 1], [312, 2], [312, 3], [311, 4], [312, 5], [312, 7], [317, 7], [318, 8], [319, 7], [319, 0], [312, 0]]}]
# Processing file: /kaggle/working/high_quality_segment/frame3094_leftImg8bit.jpg
# No objects found for frame frame3094_leftImg8bit
# Processing file: /kaggle/working/high_quality_segment/frame3134_leftImg8bit.jpg
# No objects found for frame frame3134_leftImg8bit
# Processing file: /kaggle/working/high_quality_segment/frame3263_leftImg8bit.jpg
# No objects found for frame frame3263_leftImg8bit
# Processing file: /kaggle/working/high_quality_segment/frame3276_leftImg8bit.jpg
# No objects found for frame frame3276_leftImg8bit
# Processing file: /kaggle/working/high_quality_segment/frame3334_leftImg8bit.jpg
# No objects found for frame frame3334_leftImg8bit
# Processing file: /kaggle/working/high_quality_segment/frame3348_leftImg8bit.jpg
# No objects found for frame frame3348_leftImg8bit
# Processing file: /kaggle/working/high_quality_segment/frame3486_leftImg8bit.jpg
# No objects found for frame frame3486_leftImg8bit
# Processing file: /kaggle/working/high_quality_segment/frame3532_leftImg8bit.jpg
# Objects found for frame frame3532_leftImg8bit: [{'label': 'pole', 'polygon': [[985, 477]]}]
# Processing file: /kaggle/working/high_quality_segment/frame3592_leftImg8bit.jpg
# No objects found for frame frame3592_leftImg8bit
# Processing file: /kaggle/working/high_quality_segment/frame3618_leftImg8bit.jpg
# Objects found for frame frame3618_leftImg8bit: [{'label': 'building', 'polygon': [[28, 2]]}]
# Processing file: /kaggle/working/high_quality_segment/frame3691_leftImg8bit.jpg
# No objects found for frame frame3691_leftImg8bit
# Processing file: /kaggle/working/high_quality_segment/frame3724_leftImg8bit.jpg
# No objects found for frame frame3724_leftImg8bit
# Processing file: /kaggle/working/high_quality_segment/frame3828_leftImg8bit.jpg
# No objects found for frame frame3828_leftImg8bit
# Processing file: /kaggle/working/high_quality_segment/frame3862_leftImg8bit.jpg
# No objects found for frame frame3862_leftImg8bit
# Processing file: /kaggle/working/high_quality_segment/frame3966_leftImg8bit.jpg
# No objects found for frame frame3966_leftImg8bit
# Processing file: /kaggle/working/high_quality_segment/frame3967_leftImg8bit.jpg
# Objects found for frame frame3967_leftImg8bit: [{'label': 'building', 'polygon': [[2040, 508], [2047, 508]]}, {'label': 'building', 'polygon': [[2030, 502]]}, {'label': 'building', 'polygon': [[2046, 501]]}, {'label': 'building', 'polygon': [[2042, 501]]}, {'label': 'building', 'polygon': [[2046, 499]]}, {'label': 'building', 'polygon': [[2043, 499]]}, {'label': 'building', 'polygon': [[2027, 499]]}, {'label': 'building', 'polygon': [[2032, 496], [2032, 504], [2033, 503], [2035, 503], [2036, 504], [2037, 503], [2039, 503], [2039, 496]]}, {'label': 'building', 'polygon': [[2034, 492]]}, {'label': 'building', 'polygon': [[2031, 492]]}]
# Processing file: /kaggle/working/high_quality_segment/frame4043_leftImg8bit.jpg
# No objects found for frame frame4043_leftImg8bit
# Processing file: /kaggle/working/high_quality_segment/frame4266_leftImg8bit.jpg
# No objects found for frame frame4266_leftImg8bit
# Processing file: /kaggle/working/high_quality_segment/frame4283_leftImg8bit.jpg
# No objects found for frame frame4283_leftImg8bit
# Processing file: /kaggle/working/high_quality_segment/frame4428_leftImg8bit.jpg
# No objects found for frame frame4428_leftImg8bit
# Processing file: /kaggle/working/high_quality_segment/frame4566_leftImg8bit.jpg
# Objects found for frame frame4566_leftImg8bit: [{'label': 'truck', 'polygon': [[291, 947]]}, {'label': 'truck', 'polygon': [[258, 911]]}, {'label': 'truck', 'polygon': [[256, 909]]}, {'label': 'truck', 'polygon': [[243, 833]]}, {'label': 'truck', 'polygon': [[333, 824]]}, {'label': 'truck', 'polygon': [[353, 819]]}]
# Processing file: /kaggle/working/high_quality_segment/frame4763_leftImg8bit.jpg
# No objects found for frame frame4763_leftImg8bit
# Processing file: /kaggle/working/high_quality_segment/frame4986_leftImg8bit.jpg
# No objects found for frame frame4986_leftImg8bit
# Processing file: /kaggle/working/high_quality_segment/frame5153_leftImg8bit.jpg
# No objects found for frame frame5153_leftImg8bit
# Processing file: /kaggle/working/high_quality_segment/frame5196_leftImg8bit.jpg
# No objects found for frame frame5196_leftImg8bit
# Processing file: /kaggle/working/high_quality_segment/frame5393_leftImg8bit.jpg
# No objects found for frame frame5393_leftImg8bit
# Processing file: /kaggle/working/high_quality_segment/frame5406_leftImg8bit.jpg
# No objects found for frame frame5406_leftImg8bit
# Processing file: /kaggle/working/high_quality_segment/frame5573_leftImg8bit.jpg
# No objects found for frame frame5573_leftImg8bit
# Processing file: /kaggle/working/high_quality_segment/frame5586_leftImg8bit.jpg
# No objects found for frame frame5586_leftImg8bit
# Processing file: /kaggle/working/high_quality_segment/frame5783_leftImg8bit.jpg
# No objects found for frame frame5783_leftImg8bit
# Processing file: /kaggle/working/high_quality_segment/frame6009_leftImg8bit.jpg
# No objects found for frame frame6009_leftImg8bit
# Processing file: /kaggle/working/high_quality_segment/frame6216_leftImg8bit.jpg
# No objects found for frame frame6216_leftImg8bit
# Processing file: /kaggle/working/high_quality_segment/frame6396_leftImg8bit.jpg
# No objects found for frame frame6396_leftImg8bit
# Processing file: /kaggle/working/high_quality_segment/frame6473_leftImg8bit.jpg
# No objects found for frame frame6473_leftImg8bit
# Processing file: /kaggle/working/high_quality_segment/frame6893_leftImg8bit.jpg
# No objects found for frame frame6893_leftImg8bit
# Processing file: /kaggle/working/high_quality_segment/frame6966_leftImg8bit.jpg
# No objects found for frame frame6966_leftImg8bit
# Processing file: /kaggle/working/high_quality_segment/frame7283_leftImg8bit.jpg
# No objects found for frame frame7283_leftImg8bit
# Processing file: /kaggle/working/high_quality_segment/frame7433_leftImg8bit.jpg
# No objects found for frame frame7433_leftImg8bit
# Processing file: /kaggle/working/high_quality_segment/frame7446_leftImg8bit.jpg
# No objects found for frame frame7446_leftImg8bit
# Processing file: /kaggle/working/high_quality_segment/frame8826_leftImg8bit.jpg
# No objects found for frame frame8826_leftImg8bit
# Processing file: /kaggle/working/high_quality_segment/frame9426_leftImg8bit.jpg
# No objects found for frame frame9426_leftImg8bit
# Processing file: /kaggle/working/high_quality_segment/frame10376_leftImg8bit.jpg
# No objects found for frame frame10376_leftImg8bit
# Processing file: /kaggle/working/high_quality_segment/frame10676_leftImg8bit.jpg
# No objects found for frame frame10676_leftImg8bit
# Processing file: /kaggle/working/high_quality_segment/frame10758_leftImg8bit.jpg
# No objects found for frame frame10758_leftImg8bit
# Processing file: /kaggle/working/high_quality_segment/frame11003_leftImg8bit.jpg
# No objects found for frame frame11003_leftImg8bit
# Processing file: /kaggle/working/high_quality_segment/frame11630_leftImg8bit.jpg
# No objects found for frame frame11630_leftImg8bit
# Processing file: /kaggle/working/high_quality_segment/frame12146_leftImg8bit.jpg
# No objects found for frame frame12146_leftImg8bit
# CSV file saved at: /kaggle/working/segmentation_output.csv
# Processing completed.
